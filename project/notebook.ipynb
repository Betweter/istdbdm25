# %% [markdown]
# # IST DBM 2025 Project - Omarion Aubert, Franciszek Dobrowolski
#
# The projects goal is to make a working data base answering natural language questions in the chosen domain.

# %% [markdown]
# ## List of contents
#
# To do in this cell.

# %% [markdown]
# ## Domain
#
# Todo in this cell.

# %% [markdown]
# ## Questions in natural language
#
# Todo in this cell.

# %% [markdown]
# ## ER diagram and tables
#
# Todo in this cell.

# %% [markdown]
# ## Connecting to Postgres and creating a data base

# %%
#code

# %% [markdown]
# ## Creating the tables

# %%
#code

# %% [markdown]
# ## Filling the tables
# The data comes from/was generated by ........

# %%
#code

# %% [markdown]
# ## Queries

# %% [markdown]
# ### Query nr X
# [Natural language question] to be done and repeated for all queries.

# %%
#code
